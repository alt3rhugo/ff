# %% [markdown]
# # FFusion 3.5.0 — Version 1 (Gradio, manual upload)
#
# Self-contained flow against the user's own FaceFusion fork (`alt3rhugo/ff`).
# All custom changes (Gradio public link, NSFW off, hash guard off) are already baked into the fork — **no runtime patching**.
#
# Use a **GPU runtime**: Runtime → Change runtime type → GPU.

# %%
# === CELL 1: CLONE THE FORK ===

# Verify a real GPU is attached. Use nvidia-smi (definitive): FaceFusion runs on
# onnxruntime, not torch, so torch.cuda.is_available() is irrelevant and can
# misleadingly print False even when onnxruntime CUDA works.
# !nvidia-smi

# %cd /content
# !rm -rf facefusion
# !git clone https://github.com/alt3rhugo/ff.git facefusion
# %cd facefusion

# %%
# === CELL 2: INSTALL DEPENDENCIES (latest, via the repo's own installer) ===
# install.py reads requirements.txt and swaps in onnxruntime-gpu==1.24.4 for cuda.
# --skip-conda bypasses the conda check (Colab has no conda).
# !python install.py --onnxruntime cuda --skip-conda
# Out:
# WARNING: Skipping onnxruntime as it is not installed.
# ...
#   Using cached onnxruntime_gpu-1.24.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# ...
# Using cached onnxruntime_gpu-1.24.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (252.8 MB)
# ...

# %%
# === CELL 3: LAUNCH GRADIO (public link; upload target + source in the UI) ===
# share=True is baked into the fork's layout files, so a public URL is printed.
# !mkdir -p /content/output

# !python facefusion.py run \
  --execution-providers cuda \
  --output-path /content/output \
  --processors face_swapper face_enhancer \
  --face-swapper-model hyperswap_1c_256 \
  --face-swapper-pixel-boost 512x512 \
  --face-enhancer-model gpen_bfr_512 \
  --face-enhancer-blend 10 \
  --face-enhancer-weight 0.1 \
  --face-swapper-weight 0.85 \
  --face-mask-blur 0.8 \
  --face-selector-mode one \
  --face-detector-score 0.65 \
  --face-landmarker-score 0.65 \
  --face-detector-angles 0 90 270 \
  --face-mask-types box occlusion
# Out:
# downloading: 100% 8.00/8.00 [00:00<00:00, 18.3B/s, download_providers=['github', 'huggingface'], file_name=nsfw_1.hash]
# downloading: 100% 8.00/8.00 [00:00<00:00, 11.9B/s, download_providers=['github', 'huggingface'], file_name=nsfw_2.hash]
# downloading: 100% 8.00/8.00 [00:00<00:00, 13.7B/s, download_providers=['github', 'huggingface'], file_name=nsfw_3.hash]
# downloading: 100% 76.7M/76.7M [00:01<00:00, 42.4MB/s, download_providers=['github', 'huggingface'], file_name=nsfw_1.onnx]
# downloading: 100% 21.4M/21.4M [00:00<00:00, 25.2MB/s, download_providers=['github', 'huggingface'], file_name=nsfw_2.onnx]
# downloading: 100% 342M/342M [00:07<00:00, 48.2MB/s, download_providers=['github', 'huggingface'], file_name=nsfw_3.onnx]
# downloading: 100% 8.00/8.00 [00:00<00:00, 13.5B/s, download_providers=['github', 'huggingface'], file_name=fairface.hash]
# downloading: 100% 81.2M/81.2M [00:01<00:00, 62.1MB/s, download_providers=['github', 'huggingface'], file_name=fairface.onnx]
# ...
